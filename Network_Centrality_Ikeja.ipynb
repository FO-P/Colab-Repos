# %% [markdown]
# ## Libraries

# %%
# !pip install osmnx networkx matplotlib

import osmnx as ox
import networkx as nx
import matplotlib.pyplot as plt
# Out:
# Collecting osmnx
#   Downloading osmnx-2.0.6-py3-none-any.whl.metadata (4.9 kB)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (3.5)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (3.10.0)
# Requirement already satisfied: geopandas>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from osmnx) (1.1.1)
# Requirement already satisfied: numpy>=1.22 in /usr/local/lib/python3.12/dist-packages (from osmnx) (2.0.2)
# Requirement already satisfied: pandas>=1.4 in /usr/local/lib/python3.12/dist-packages (from osmnx) (2.2.2)
# Requirement already satisfied: requests>=2.27 in /usr/local/lib/python3.12/dist-packages (from osmnx) (2.32.4)
# Requirement already satisfied: shapely>=2.0 in /usr/local/lib/python3.12/dist-packages (from osmnx) (2.1.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: pyogrio>=0.7.2 in /usr/local/lib/python3.12/dist-packages (from geopandas>=1.0.1->osmnx) (0.11.1)
# Requirement already satisfied: pyproj>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from geopandas>=1.0.1->osmnx) (3.7.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.4->osmnx) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.4->osmnx) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.27->osmnx) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.27->osmnx) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.27->osmnx) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.27->osmnx) (2025.10.5)
# Downloading osmnx-2.0.6-py3-none-any.whl (101 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.5/101.5 kB 3.3 MB/s eta 0:00:00
# Installing collected packages: osmnx
# Successfully installed osmnx-2.0.6

# %% [markdown]
# ##Load the street network graph from OpenStreetMap

# %%
place_name = "Kaduna South, Kaduna, Nigeria"
gdf = ox.geocode_to_gdf(place_name)
# Get the graph from the polygon
G = ox.graph_from_polygon(gdf['geometry'].iloc[0], network_type="drive")

# %%
print("Graph information:")
print(G)
# Out:
# Graph information:
# MultiDiGraph with 2199 nodes and 6059 edges

# %% [markdown]
# ##Calculate degree distribution

# %%
# Get degrees for all nodes
degrees = [val for (node, val) in G.degree()]

# %%
degree_dict = dict(G.degree())
degrees = list(degree_dict.values())

# %% [markdown]
# ## Plot histogram of degrees

# %%
plt.figure(figsize=(8,6))
plt.hist(degrees, bins=range(1, max(degrees)+1), color='teal', edgecolor='black')
plt.title(f"Degree Distribution of Road Network in {place_name}")
plt.xlabel("Node Degree")
plt.ylabel("Frequency")
plt.grid(alpha=0.3)
plt.show()

# %% [markdown]
# ##Degree Distribution Statistics

# %%
# Degree distribution statistics
import pandas as pd
degree_freq = nx.degree_histogram(G)
degree_df = pd.DataFrame({'Degree': range(len(degree_freq)), 'Frequency': degree_freq})
display(degree_df.head(10))
# Out:
#    Degree  Frequency
# 0       0          0
# 1       1          0
# 2       2        312
# 3       3         32
# 4       4        199
# 5       5          6
# 6       6       1314
# 7       7          0
# 8       8        336

# %%
import numpy as np

print("\nDegree Statistics")
print(f"Number of nodes: {len(G.nodes)}")
print(f"Average degree: {np.mean(degrees):.2f}")
print(f"Maximum degree: {np.max(degrees)}")
print(f"Number of isolated nodes (degree 0): {sum(np.array(degrees) == 0)}")
# Out:
# Degree Statistics
# Number of nodes: 2199
# Average degree: 5.51
# Maximum degree: 8
# Number of isolated nodes (degree 0): 0

# %% [markdown]
# ### Visualizing the graph

# %%
fig, ax = ox.plot_graph(G, node_size=8, node_color='blue', edge_color='black', bgcolor='white')

# %% [markdown]
# ##Network centrality plotted for each node

# %%
gdf_nodes, gdf_edges = ox.convert.graph_to_gdfs(G)
G = ox.convert.graph_from_gdfs(gdf_nodes, gdf_edges, graph_attrs=G.graph)

D = ox.convert.to_digraph(G)

bc = nx.betweenness_centrality(D)
nx.set_node_attributes(G, values=bc, name="bc")

nc = ox.plot.get_node_colors_by_attr(G, "bc", cmap="plasma")
fig, ax = ox.plot.plot_graph(
    G, bgcolor="k", node_color=nc, node_size=50, edge_linewidth=2, edge_color="#333333"
)

cc = nx.closeness_centrality(D, distance="travel_time")
nx.set_node_attributes(G, values=cc, name="cc")

nc_cc = ox.plot.get_node_colors_by_attr(G, "cc", cmap="plasma")
fig, ax = ox.plot.plot_graph(
    G, bgcolor="k", node_color=nc_cc, node_size=50, edge_linewidth=2, edge_color="#333333"
)
ox.io.save_graph_geopackage(G, filepath="./graph.gpkg")
ox.io.save_graphml(G, filepath="./graph.graphml")

# %% [markdown]
# ##hypergraphx Basics  Task 2

# %% [markdown]
# ##Libraries & Imports

# %%
# !pip install hypergraphx
# !pip install osmnx
# Out:
# Collecting hypergraphx
#   Downloading hypergraphx-1.7.8-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from hypergraphx) (2.0.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from hypergraphx) (1.16.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from hypergraphx) (3.5)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from hypergraphx) (2.2.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (from hypergraphx) (1.6.1)
# Requirement already satisfied: pytest in /usr/local/lib/python3.12/dist-packages (from hypergraphx) (8.4.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from hypergraphx) (3.10.0)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.12/dist-packages (from hypergraphx) (0.13.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->hypergraphx) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->hypergraphx) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->hypergraphx) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->hypergraphx) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->hypergraphx) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->hypergraphx) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->hypergraphx) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->hypergraphx) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->hypergraphx) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->hypergraphx) (2025.2)
# Requirement already satisfied: iniconfig>=1 in /usr/local/lib/python3.12/dist-packages (from pytest->hypergraphx) (2.3.0)
# Requirement already satisfied: pluggy<2,>=1.5 in /usr/local/lib/python3.12/dist-packages (from pytest->hypergraphx) (1.6.0)
# Requirement already satisfied: pygments>=2.7.2 in /usr/local/lib/python3.12/dist-packages (from pytest->hypergraphx) (2.19.2)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->hypergraphx) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->hypergraphx) (3.6.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->hypergraphx) (1.17.0)
# Downloading hypergraphx-1.7.8-py3-none-any.whl (126 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 126.2/126.2 kB 3.2 MB/s eta 0:00:00
# Installing collected packages: hypergraphx
# Successfully installed hypergraphx-1.7.8
# Collecting osmnx
#   Downloading osmnx-2.0.6-py3-none-any.whl.metadata (4.9 kB)
# Requirement already satisfied: geopandas>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from osmnx) (1.1.1)
# Requirement already satisfied: networkx>=2.5 in /usr/local/lib/python3.12/dist-packages (from osmnx) (3.5)
# Requirement already satisfied: numpy>=1.22 in /usr/local/lib/python3.12/dist-packages (from osmnx) (2.0.2)
# Requirement already satisfied: pandas>=1.4 in /usr/local/lib/python3.12/dist-packages (from osmnx) (2.2.2)
# Requirement already satisfied: requests>=2.27 in /usr/local/lib/python3.12/dist-packages (from osmnx) (2.32.4)
# Requirement already satisfied: shapely>=2.0 in /usr/local/lib/python3.12/dist-packages (from osmnx) (2.1.2)
# Requirement already satisfied: pyogrio>=0.7.2 in /usr/local/lib/python3.12/dist-packages (from geopandas>=1.0.1->osmnx) (0.11.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from geopandas>=1.0.1->osmnx) (25.0)
# Requirement already satisfied: pyproj>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from geopandas>=1.0.1->osmnx) (3.7.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.4->osmnx) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.4->osmnx) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.4->osmnx) (2025.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.27->osmnx) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.27->osmnx) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.27->osmnx) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.27->osmnx) (2025.10.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas>=1.4->osmnx) (1.17.0)
# Downloading osmnx-2.0.6-py3-none-any.whl (101 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.5/101.5 kB 2.1 MB/s eta 0:00:00
# Installing collected packages: osmnx
# Successfully installed osmnx-2.0.6

# %%
import sys
import osmnx as ox

# %%
sys.path.append("..")

from hypergraphx.generation.scale_free import scale_free_hypergraph
from hypergraphx.linalg import *
from hypergraphx.representations.projections import bipartite_projection, clique_projection
from hypergraphx.generation.random import *
from hypergraphx.readwrite.save import save_hypergraph
from hypergraphx.readwrite.load import load_hypergraph
from hypergraphx.viz.draw_hypergraph import draw_hypergraph

# %%
place_name = "Kaduna South, Kaduna, Nigeria"
gdf = ox.geocode_to_gdf(place_name)
G = ox.graph_from_polygon(gdf['geometry'].iloc[0], network_type="drive")

# %%
major_road_name = "Nnamdi Azikwe Way"
edges = [(u, v, k) for u, v, k, data in G.edges(keys=True, data=True) if data.get("name") == major_road_name]

# Collect all unique node endpoints for this road
nodes_on_road = set()
for u, v, k in edges:
    nodes_on_road.add(u)
    nodes_on_road.add(v)
road_hyperedge = tuple(nodes_on_road)

# %%
from hypergraphx.generation.scale_free import Hypergraph
hyperedges_from_segments = [(u, v) for u, v, k in edges]
H = Hypergraph(hyperedges_from_segments)

print(H)
# Out:
# Hypergraph with 115 nodes and 113 edges.
# Distribution of hyperedge sizes: {2: 113}

# %%
H.get_edges()
# Out:
# [(1733611836, 2409313178),
#  (1733611837, 5253432446),
#  (1733611838, 1733612111),
#  (1733611867, 1733611891),
#  (1733611872, 1733612102),
#  (1733611867, 1733611874),
#  (1733611876, 1733611948),
#  (1733611881, 1733611980),
#  (1733611874, 1733611887),
#  (1733611891, 5251519005),
#  (1733611892, 1733611923),
#  (1733611895, 1733612129),
#  (1733611896, 1733612132),
#  (1733611897, 1733612130),
#  (1733611911, 1733612142),
#  (1733611892, 1733611912),
#  (1733611917, 1733612076),
#  (1733611923, 1733611999),
#  (1733611934, 1733611967),
#  (1733611887, 1733611946),
#  (1733611948, 5253359597),
#  (1733611951, 5665640822),
#  (1733611956, 1733612124),
#  (1733611958, 11831296798),
#  (1733611838, 1733611967),
#  (1733611979, 1733612127),
#  (1733611980, 1733612122),
#  (1733611983, 1733611995),
#  (1733611876, 1733611984),
#  (1733611986, 5243681297),
#  (1733611995, 1733612048),
#  (1733611911, 1733611998),
#  (1733611999, 5243681383),
#  (1733612010, 1733612153),
#  (1733612011, 2409313254),
#  (1733612024, 4712449591),
#  (1733611951, 1733612028),
#  (1733612048, 10825912383),
#  (1733612061, 1733612067),
#  (1733612024, 1733612062),
#  (1733612067, 1733612087),
#  (1733611917, 1733612069),
#  (1733612072, 11831296803),
#  (1733611897, 1733612074),
#  (1733612075, 1733612166),
#  (1733612076, 1733612128),
#  (1733612074, 1733612080),
#  (1733611979, 1733612087),
#  (1733612069, 1733612088),
#  (1733611934, 1733612092),
#  (1733611998, 1733612094),
# ((1733612011, 2409313254), 34)
# ((1733612024, 4712449591), 35)
# ((1733611951, 1733612028), 36)
# ((1733612048, 10825912383), 37)
# ((1733612061, 1733612067), 38)
# ((1733612024, 1733612062), 39)
# ((1733612067, 1733612087), 40)
# ((1733611917, 1733612069), 41)
# ((1733612072, 11831296803), 42)
# ((1733611897, 1733612074), 43)
# ((1733612075, 1733612166), 44)
# ((1733612076, 1733612128), 45)
# ((1733612074, 1733612080), 46)
# ((1733611979, 1733612087), 47)
# ((1733612069, 1733612088), 48)
# ((1733611934, 1733612092), 49)
# ((1733611998, 1733612094), 50)
# ((1733612100, 1733612161), 51)
# ((1733612101, 5253432468), 52)
# ((1733612010, 1733612102), 53)
# ((1733612111, 7449693953), 54)
# ((1733612092, 1733612122), 55)
# ((1733611984, 1733612124), 56)
# ((1733611956, 1733612127), 57)
# ((1733612061, 1733612128), 58)
# ((1733612129, 11553137178), 59)
# ((1733611881, 1733612130), 60)
# ((1733611983, 1733612132), 61)
# ((1733612135, 5253432515), 62)
# ((1733611872, 1733612142), 63)
# ((1733612143, 5243681590), 64)
# ((1733611958, 1733612147), 65)
# ((1733612062, 1733612152), 66)
# ((1733612153, 10825912374), 67)
# ((1733612072, 1733612155), 68)
# ((1733612028, 1733612161), 69)
# ((1733612165, 5253284613), 70)
# ((1733611895, 1733612166), 71)
# ((1733612143, 2409313178), 72)
# ((1733612101, 2409313254), 73)
# ((2409313284, 5251519006), 74)
# ((3334174715, 5243681587), 75)
# ((3334174717, 5243643917), 76)
# ((1733611946, 4712449069), 77)
# ((2409313284, 4712449590), 78)
# ((1733612135, 4712449591), 79)
# ((1733611912, 4731354552), 80)
# ((5185328041, 5185328117), 81)
# ((5187489284, 5187489301), 82)
# ((4731354552, 5187489301), 83)
# ((5243643850, 5243643862), 84)
# ((5243643862, 5243643867), 85)
# ((1733611986, 5243643867), 86)
# ((5243643850, 5243643917), 87)
# ((5185328041, 5243644343), 88)
# ((5243644343, 5243681297), 89)
# ((1733612075, 5243681383), 90)
# ((3334174717, 5243681587), 91)
# ((3334174715, 5243681590), 92)
# ((1733612155, 5249724693), 93)
# ((1733612152, 5251519005), 94)
# ((1733611837, 5251519006), 95)
# ((1733612165, 5253284547), 96)
# ((5253284547, 5253284554), 97)
# ((4712449590, 5253284613), 98)
# ((4712449069, 5253359597), 99)
# ((5253432446, 5253432461), 100)
# ((5253432461, 12361321322), 101)
# ((1733612080, 5253432468), 102)
# ((1733611988, 5253432515), 103)
# ((1733611836, 5665640822), 104)
# ((1733611896, 7449693953), 105)
# ((1733612088, 10825912374), 106)
# ((5249724693, 10825912383), 107)
# ((1733612147, 11553137178), 108)
# ((5187489284, 11553260113), 109)
# ((1733612094, 11831296798), 110)
# ((1733612100, 11831296803), 111)
# ((1733612011, 12361321322), 112)

# %%
segment = (1733611836, 2409313178)
segment_weight = H.get_weight(segment)

# %%
H.get_weight((1733611836, 2409313178))
# Out:
# 1

# %%
H.is_connected()
# Out:
# False

# %%
H.add_edge((1733611836, 2409313178), weight=1)

# %%
draw_hypergraph(H)

# %%
H.is_uniform()
# Out:
# True
